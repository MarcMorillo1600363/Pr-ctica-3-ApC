# %% [markdown]
# # CAS KAGGLE POKEMON

# %% [markdown]
# ### Importar BD

# %% [markdown]
# El primer que fem és importar les llibreries necessàries i la nostra base de dades, que en aquest cas tracta sobre Pokémon.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_curve, auc, classification_report, roc_auc_score, plot_confusion_matrix, confusion_matrix
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
import time

dataset = pd.read_csv(r"C:\Users\marcm\Downloads\pokemon.csv")

# %% [markdown]
# ### Analitzar BD

# %% [markdown]
# Ara mostrarem algunes de les dades per poder entendre millor que estem buscant, i altres dades informatives per veure si tenim algun problema previ, com per exemple nulls o variables contínues.

# %%
pd.set_option('display.max_columns', None)
dataset.head(774)
# Out:
#                              abilities  against_bug  against_dark  \
# 0          ['Overgrow', 'Chlorophyll']          1.0           1.0
# 1          ['Overgrow', 'Chlorophyll']          1.0           1.0
# 2          ['Overgrow', 'Chlorophyll']          1.0           1.0
# 3             ['Blaze', 'Solar Power']          0.5           1.0
# 4             ['Blaze', 'Solar Power']          0.5           1.0
# ..                                 ...          ...           ...
# 769  ['Water Compaction', 'Sand Veil']          0.5           2.0
# 770         ['Innards Out', 'Unaware']          1.0           1.0
# 771                   ['Battle Armor']          1.0           1.0
# 772                     ['RKS System']          1.0           1.0
# 773                   ['Shields Down']          0.5           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 0               1.0               0.5            0.5            0.5
# 1               1.0               0.5            0.5            0.5
# 2               1.0               0.5            0.5            0.5
# 3               1.0               1.0            0.5            1.0
# 4               1.0               1.0            0.5            1.0
# ..              ...               ...            ...            ...
# 769             1.0               0.0            1.0            0.0
# 770             1.0               2.0            1.0            1.0
# 771             1.0               1.0            1.0            2.0
# 772             1.0               1.0            1.0            2.0
# 773             1.0               2.0            1.0            1.0
#
#      against_fire  against_flying  against_ghost  against_grass  \
# 0             2.0             2.0            1.0           0.25
# 1             2.0             2.0            1.0           0.25
# 2             2.0             2.0            1.0           0.25
# 3             0.5             1.0            1.0           0.50
# 4             0.5             1.0            1.0           0.50
# ..            ...             ...            ...            ...
# 769           1.0             1.0            2.0           2.00
# 770           0.5             1.0            1.0           2.00
# 771           1.0             1.0            0.0           1.00
# 772           1.0             1.0            0.0           1.00
# 773           0.5             0.5            1.0           1.00
#
#      against_ground  against_ice  against_normal  against_poison  \
# 0               1.0          2.0             1.0            1.00
# 1               1.0          2.0             1.0            1.00
# 2               1.0          2.0             1.0            1.00
# 3               2.0          0.5             1.0            1.00
# 4               2.0          0.5             1.0            1.00
# ..              ...          ...             ...             ...
# 769             1.0          2.0             0.0            0.25
# 770             1.0          0.5             1.0            1.00
# 771             1.0          1.0             1.0            1.00
# 772             1.0          1.0             1.0            1.00
# 773             0.0          2.0             0.5            0.50
#
#      against_psychic  against_rock  against_steel  against_water  attack  \
# 0                2.0           1.0            1.0            0.5      49
# 1                2.0           1.0            1.0            0.5      62
# 2                2.0           1.0            1.0            0.5     100
# 3                1.0           2.0            0.5            2.0      52
# 4                1.0           2.0            0.5            2.0      64
# ..               ...           ...            ...            ...     ...
# 769              1.0           0.5            1.0            2.0      75
# 770              1.0           1.0            0.5            0.5      60
# 771              1.0           1.0            1.0            1.0      95
# 772              1.0           1.0            1.0            1.0      95
# 773              1.0           2.0            2.0            2.0     100
#
#      base_egg_steps  base_happiness  base_total              capture_rate  \
# 0              5120              70         318                        45
# 1              5120              70         405                        45
# 2              5120              70         625                        45
# 3              5120              70         309                        45
# 4              5120              70         405                        45
# ..              ...             ...         ...                       ...
# 769            3840              70         480                        60
# 770            3840              70         410                        60
# 771           30720               0         534                         3
# 772           30720               0         570                         3
# 773            6400              70         500  30 (Meteorite)255 (Core)
#
#             classfication  defense  experience_growth  height_m  hp  \
# 0            Seed Pokémon       49            1059860       0.7  45
# 1            Seed Pokémon       63            1059860       1.0  60
# 2            Seed Pokémon      123            1059860       2.0  80
# 3          Lizard Pokémon       43            1059860       0.6  39
# 4           Flame Pokémon       58            1059860       1.1  58
# ..                    ...      ...                ...       ...  ..
# 769   Sand Castle Pokémon      110            1000000       1.3  85
# 770  Sea Cucumber Pokémon      130             800000       0.3  55
# 771     Synthetic Pokémon       95            1250000       1.9  95
# 772     Synthetic Pokémon       95            1250000       2.3  95
# 773        Meteor Pokémon       60            1059860       0.3  60
#
#         japanese_name        name  percentage_male  pokedex_number  sp_attack  \
# 0    Fushigidaneフシギダネ   Bulbasaur             88.1               1         65
# 1     Fushigisouフシギソウ     Ivysaur             88.1               2         80
# 2    Fushigibanaフシギバナ    Venusaur             88.1               3        122
# 3        Hitokageヒトカゲ  Charmander             88.1               4         60
# 4         Lizardoリザード  Charmeleon             88.1               5         80
# ..                ...         ...              ...             ...        ...
# 769   Sirodethnaシロデスナ   Palossand             50.0             770        100
# 770  Namakobushiナマコブシ   Pyukumuku             50.0             771         30
# 771  Type: Nullタイプ：ヌル  Type: Null              NaN             772         95
# 772     Silvadyシルヴァディ    Silvally              NaN             773         95
# 773         Metenoメテノ      Minior              NaN             774        100
#
#      sp_defense  speed   type1   type2  weight_kg  generation  is_legendary
# 0            65     45   grass  poison        6.9           1             0
# 1            80     60   grass  poison       13.0           1             0
# 2           120     80   grass  poison      100.0           1             0
# 3            50     65    fire     NaN        8.5           1             0
# 4            65     80    fire     NaN       19.0           1             0
# ..          ...    ...     ...     ...        ...         ...           ...
# 769          75     35   ghost  ground      250.0           7             0
# 770         130      5   water     NaN        1.2           7             0
# 771          95     59  normal     NaN      120.5           7             0
# 772          95     95  normal     NaN      100.5           7             0
# 773          60    120    rock  flying       40.0           7             0
#
# [774 rows x 41 columns]

# %%
dataset.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# 25%         1.000000       0.500000      0.500000        1.000000
# 50%         1.000000       1.000000      1.000000        1.000000
# 75%         1.000000       1.000000      2.000000        1.000000
# max         4.000000       4.000000      4.000000        4.000000
#
#        against_ghost  against_grass  against_ground  against_ice  \
# count     801.000000     801.000000      801.000000   801.000000
# mean        0.985019       1.034020        1.098002     1.208177
# std         0.558256       0.788896        0.738818     0.735356
# min         0.000000       0.250000        0.000000     0.250000
# 25%         1.000000       0.500000        1.000000     0.500000
# 50%         1.000000       1.000000        1.000000     1.000000
# 75%         1.000000       1.000000        1.000000     2.000000
# max         4.000000       4.000000        4.000000     4.000000
#
#        against_normal  against_poison  against_psychic  against_rock  \
# count      801.000000      801.000000       801.000000    801.000000
# mean         0.887016        0.975343         1.005306      1.250312
# std          0.266106        0.549375         0.495183      0.697148
# min          0.000000        0.000000         0.000000      0.250000
# 25%          1.000000        0.500000         1.000000      1.000000
# 50%          1.000000        1.000000         1.000000      1.000000
# 75%          1.000000        1.000000         1.000000      2.000000
# max          1.000000        4.000000         4.000000      4.000000
#
#        against_steel  against_water      attack  base_egg_steps  \
# count     801.000000     801.000000  801.000000      801.000000
# mean        0.983458       1.058365   77.857678     7191.011236
# std         0.500117       0.606562   32.158820     6558.220422
# min         0.250000       0.250000    5.000000     1280.000000
# 25%         0.500000       0.500000   55.000000     5120.000000
# 50%         1.000000       1.000000   75.000000     5120.000000
# 75%         1.000000       1.000000  100.000000     6400.000000
# max         4.000000       4.000000  185.000000    30720.000000
#
#        base_happiness  base_total     defense  experience_growth    height_m  \
# count      801.000000  801.000000  801.000000       8.010000e+02  781.000000
# mean        65.362047  428.377029   73.008739       1.054996e+06    1.163892
# std         19.598948  119.203577   30.769159       1.602558e+05    1.080326
# min          0.000000  180.000000    5.000000       6.000000e+05    0.100000
# 25%         70.000000  320.000000   50.000000       1.000000e+06    0.600000
# 50%         70.000000  435.000000   70.000000       1.000000e+06    1.000000
# 75%         70.000000  505.000000   90.000000       1.059860e+06    1.500000
# max        140.000000  780.000000  230.000000       1.640000e+06   14.500000
#
#                hp  percentage_male  pokedex_number   sp_attack  sp_defense  \
# count  801.000000       703.000000      801.000000  801.000000  801.000000
# mean    68.958801        55.155761      401.000000   71.305868   70.911361
# std     26.576015        20.261623      231.373075   32.353826   27.942501
# min      1.000000         0.000000        1.000000   10.000000   20.000000
# 25%     50.000000        50.000000      201.000000   45.000000   50.000000
# 50%     65.000000        50.000000      401.000000   65.000000   66.000000
# 75%     80.000000        50.000000      601.000000   91.000000   90.000000
# max    255.000000       100.000000      801.000000  194.000000  230.000000
#
#             speed   weight_kg  generation  is_legendary
# count  801.000000  781.000000  801.000000    801.000000
# mean    66.334582   61.378105    3.690387      0.087391
# std     28.907662  109.354766    1.930420      0.282583
# min      5.000000    0.100000    1.000000      0.000000
# 25%     45.000000    9.000000    2.000000      0.000000
# 50%     65.000000   27.300000    4.000000      0.000000
# 75%     85.000000   64.800000    5.000000      0.000000
# max    180.000000  999.900000    7.000000      1.000000

# %% [markdown]
# Aquí hem pogut comprendre la nostra BD, que tracta sobre Pokémon. La BD conté informació sobre 802 Pokémon, de primera a sèptima generació. Les nostres variables són les estadístiques i informació individual sobre cada Pokémon, com pot ser el seu pes, nom, tipus, quins tipus d'atacs són eficaços contra ells, les seves estadístiques com atac, defensa, etc.
#
# Després de veure una mica les dades observem que la nostra variable objectiu serà is_legendary, és a dir volem predir si un Pokémon és o no legendary.

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# Hem pogut veure que tenim valors nulls, principalment a la variable type2 i percentage_male, això és pel fet que alguns Pokémons només tenen 1 tipus, i, per tant, el segon és null, i que molts legendaris no tenen un gènere definit.
#
# També hem pogut veure que a la fila 773 tenim un valor estrany a la variable capture_rate, que en comptes de ser un valor int té una sèrie de valors str, en conseqüència eliminem aquesta fila.

# %%
#eliminem la fila que dona problemes
dataset = dataset.drop(773)

#comprovem els nulls
dataset.isnull().sum()
# Out:
# abilities              0
# against_bug            0
# against_dark           0
# against_dragon         0
# against_electric       0
# against_fairy          0
# against_fight          0
# against_fire           0
# against_flying         0
# against_ghost          0
# against_grass          0
# against_ground         0
# against_ice            0
# against_normal         0
# against_poison         0
# against_psychic        0
# against_rock           0
# against_steel          0
# against_water          0
# attack                 0
# base_egg_steps         0
# base_happiness         0
# base_total             0
# capture_rate           0
# classfication          0
# defense                0
# experience_growth      0
# height_m              20
# hp                     0
# japanese_name          0
# name                   0
# percentage_male       97
# pokedex_number         0
# sp_attack              0
# sp_defense             0
# speed                  0
# type1                  0
# type2                384
# weight_kg             20
# generation             0
# is_legendary           0
# dtype: int64

# %% [markdown]
# Aquí podem veure el comentat anteriorment, la variable type2 i percentage_male tenen molts nulls, però són necessaris.
#
# En canvi, veiem que també tenim nulls a les variables weight_kg i height_m. Aquests sí que els considerem error, per tant, eliminarem les files respectives. Però primer transformarem els nulls de la variable type2 i percentage_male en 0.

# %%
dataset = dataset.fillna({'type2': 0})
dataset['type2'] = dataset['type2'].astype(str)

dataset = dataset.fillna({'percentage_male': 0})
dataset['percentage_male'] = dataset['percentage_male'].astype(float)

# %% [markdown]
# Amb aquesta funció hem transformat els nulls de la variable type2 i percentage_male en 0, per tant, ara podrem eliminar les files que tinguin un null en altres variables.

# %%
print('nulls variable type2')
print(dataset['type2'].isnull().sum())
print('nulls variable percentage_male')
print(dataset['percentage_male'].isnull().sum())
# Out:
# nulls variable type2
# 0
# nulls variable percentage_male
# 0

# %% [markdown]
# Observem que la variable type2 i percentage_male ara tenen 0 valors a null, per tant, podem eliminar la resta de files amb nulls.

# %%
dataset = dataset.dropna()
dataset.isnull().sum()
# Out:
# abilities            0
# against_bug          0
# against_dark         0
# against_dragon       0
# against_electric     0
# against_fairy        0
# against_fight        0
# against_fire         0
# against_flying       0
# against_ghost        0
# against_grass        0
# against_ground       0
# against_ice          0
# against_normal       0
# against_poison       0
# against_psychic      0
# against_rock         0
# against_steel        0
# against_water        0
# attack               0
# base_egg_steps       0
# base_happiness       0
# base_total           0
# capture_rate         0
# classfication        0
# defense              0
# experience_growth    0
# height_m             0
# hp                   0
# japanese_name        0
# name                 0
# percentage_male      0
# pokedex_number       0
# sp_attack            0
# sp_defense           0
# speed                0
# type1                0
# type2                0
# weight_kg            0
# generation           0
# is_legendary         0
# dtype: int64

# %% [markdown]
# Observem que ja no hi ha nulls, per tant, podem continuar treballant amb la BD.
#
# Ara, com hem vist que hi ha variables que són strings, les transformarem en tipus int per poder treballar amb més facilitat, aquelles que són paraules transformarem cada paraula en un valor int, de forma que totes les paraules iguals tinguin el mateix valor int.

# %%
dataset['capture_rate'] = dataset['capture_rate'].astype(int)

variablesStr = ['abilities','classfication','type1','type2','name','japanese_name']

for variable in variablesStr:
    le = preprocessing.LabelEncoder()
    le.fit(dataset[variable])
    dataset[variable] = le.transform(dataset[variable])

# %% [markdown]
# Continuem observant les correlacions

# %%
correlacio = dataset.corr()

plt.figure()

ax = sns.heatmap(correlacio, annot=True, linewidths=.5 ,annot_kws={'fontsize':5})

# %% [markdown]
# Com d'aquesta manera no es veuen bé les correlacions les representaré d'una altra manera.

# %%
correlacions = dataset.corr()['is_legendary'].to_frame().T 
plt.figure(figsize=(80,1))
plt.subplots(figsize=(80, 1))
sns.heatmap(correlacions, linewidths=0.3, annot=True)
plt.show()

# %% [markdown]
# D'aquestes correlacions podem deduir i descartar moltes coses.
#
# La principal idea que veiem és que la variable que té una correlació més important amb el nostre objectiu és base_egg_steps, amb una correlació del 87%.
#
# També veiem que hi ha moltes variables que no té sentit relacionar-les amb la nostra variable objectiu is_legendary, com és el cas de les variables name, japanese_name, generation i pokedex_number entre d'altres.
#
# A més podem descartar variables com per exemple tots els against_X, ja que es pot veure que tenen una  correlacio molt petita, fins i tot <0, i és normal perquè aquestes variables són en funció del tipus del Pokémon, i un Pokémon llegendari pot ser de qualsevol tipus.
#
# Podem comprovar també que les variables amb millor correlació estan relacionades amb les estadístiques individuals del Pokémon, ja que els pokémons llegendaris acostumen a ser més poderosos.
#
# Per últim, podem veure que hi ha 3 variables amb una correlació molt negativa, aquestes correlacions també són importants pel fet que vol dir que la variable està molt relacionada amb la variable objectiu, però de forma inversa.

# %% [markdown]
# Per tant, procedim a eliminar les variables innecessàries.

# %%
dataset = dataset.drop(['abilities','against_bug','against_dark','against_dragon','against_electric','against_fairy','against_fight','against_fire','against_flying','against_ghost','against_grass','against_ground','against_ice','against_normal','against_poison','against_psychic','against_rock','against_steel','against_water','classfication','pokedex_number','name','japanese_name','type1','type2','generation'],axis = 1)
dataset.head(10)
# Out:
#    attack  base_egg_steps  base_happiness  base_total  capture_rate  defense  \
# 0      49            5120              70         318            45       49
# 1      62            5120              70         405            45       63
# 2     100            5120              70         625            45      123
# 3      52            5120              70         309            45       43
# 4      64            5120              70         405            45       58
# 5     104            5120              70         634            45       78
# 6      48            5120              70         314            45       65
# 7      63            5120              70         405            45       80
# 8     103            5120              70         630            45      120
# 9      30            3840              70         195           255       35
#
#    experience_growth  height_m  hp  percentage_male  sp_attack  sp_defense  \
# 0            1059860       0.7  45             88.1         65          65
# 1            1059860       1.0  60             88.1         80          80
# 2            1059860       2.0  80             88.1        122         120
# 3            1059860       0.6  39             88.1         60          50
# 4            1059860       1.1  58             88.1         80          65
# 5            1059860       1.7  78             88.1        159         115
# 6            1059860       0.5  44             88.1         50          64
# 7            1059860       1.0  59             88.1         65          80
# 8            1059860       1.6  79             88.1        135         115
# 9            1000000       0.3  45             50.0         20          20
#
#    speed  weight_kg  is_legendary
# 0     45        6.9             0
# 1     60       13.0             0
# 2     80      100.0             0
# 3     65        8.5             0
# 4     80       19.0             0
# 5    100       90.5             0
# 6     43        9.0             0
# 7     58       22.5             0
# 8     78       85.5             0
# 9     45        2.9             0

# %%
correlacions = dataset.corr()['is_legendary'].to_frame().T 
plt.figure(figsize=(80,1.5))
plt.subplots(figsize=(80, 1.5))
sns.heatmap(correlacions, linewidths=0.3, annot=True)
plt.show()

# %% [markdown]
# Ara podem observar que ens hem quedat amb aquelles variables que més afecten la nostra variable objectiu.
#
# El següent pas a fer és normalitzar les variables, ja que hi ha algunes que poden tenir uns valors molt dispersos.

# %%
variableObjectiu = dataset['is_legendary']
dataset = dataset.drop(['is_legendary'],axis = 1)

datasetNormalitzat = preprocessing.normalize(dataset)

# %% [markdown]
# # Models

# %% [markdown]
# El primer que hem de fer abans de començar a fer models és dividir la nostra BD en train i test, utilitzarem un 80% de les dades pel train i el 20% restant pel test.

# %%
trainX, testX, trainY, testY = train_test_split(datasetNormalitzat, variableObjectiu, train_size=0.8)

# %% [markdown]
# ### Histograma

# %% [markdown]
# Com la BD a la variable objectiu té pocs valors 1 comprovem que s'hagin repartit més o menys equivalentment, ja que si tots els 1 estan al test o train causarà un problema en fer l'entrenament.

# %%
plt.figure(figsize=(10,7))
sns.displot(trainY, color='b', kde=False)
plt.ylabel('quantitat')
plt.title('train')
plt.show()


plt.figure(figsize=(10,7))
sns.displot(testY, color='b', kde=False)
plt.ylabel('quantitat')
plt.title('test')
plt.show()

# %% [markdown]
# Observem que s'han repartit de forma correcta.

# %% [markdown]
# ### Random Forest

# %% [markdown]
# El primer model que provem és el Random Forest.

# %%
tempsInici = time.time()

#entrenem les nostres dades
entrenamentRandomForest = RandomForestClassifier(n_estimators=1000, random_state = 1807)
entrenamentRandomForest.fit(trainX, trainY)

#calculem les accuracy
accuracyRandomForestTrain = round(entrenamentRandomForest.score(trainX, trainY)*100,2)
print('accuracy train:')
print(round(accuracyRandomForestTrain, 2), '%')

accuracyRandomForestTest = round(entrenamentRandomForest.score(testX, testY)*100,2)
print('accuracy test:')
print(round(accuracyRandomForestTest, 2), '%')

prediccioY = entrenamentRandomForest.predict(testX)
accuracyRandomForest = round(accuracy_score(testY, prediccioY)*100,2)
print('accuracy real:')
print(round(accuracyRandomForest,2), '%')

tempsFin = time.time()
print(tempsFin - tempsInici)
# Out:
# accuracy train:
# 100.0 %
# accuracy test:
# 100.0 %
# accuracy real:
# 100.0 %
# 3.506856679916382

# %% [markdown]
# Com el resultat és molt bo, mirem la corba roc i la confusion matrix per veure si és correcte o si hi ha hagut algun problema.

# %%
fpr = {}
tpr = {}
roc_auc = {}
probabilitat = entrenamentRandomForest.predict_proba(testX)
#in range(2) porque mi variable objetivo es 1 o 0
for i in range(2):
    fpr[i], tpr[i],_  = roc_curve(testY == i, probabilitat[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
plt.figure()
for i in range(2):
    plt.plot(fpr[i], tpr[i], label='Class {0} (area = {1:0.2f})' ''.format(i, roc_auc[i]))
plt.legend()

# %%
confusion_matrix(testY,prediccioY)
plot_confusion_matrix(entrenamentRandomForest, testX, testY, cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# Podem veure que el random forest ens dona uns molt bons resultats

# %% [markdown]
# ### SVM

# %% [markdown]
# A continuació del Random Forest provem el SVM per veure si és igual d'efectiu en el nostre cas.

# %%
tempsInici = time.time()

#primer entrenem les dades
entrenamentSVM = svm.SVC(probability=True)
entrenamentSVM.fit(trainX,trainY)

#fem la prediccio
prediccioSVM = entrenamentSVM.predict(testX)

#calculem la acuracy
accuracySVM = round(accuracy_score(testY, prediccioSVM)*100, 2)

print('accuracy SVM:')
print(round(accuracySVM,2), '%')

print('temps:')
tempsFin = time.time()
print(tempsFin - tempsInici)
# Out:
# accuracy SVM:
# 90.38 %
# temps:
# 0.04074907302856445

# %% [markdown]
# Com el resultat també és bo, mirem la corba roc per veure si és correcte o si hi ha hagut algun problema.

# %%
fpr = {}
tpr = {}
roc_auc = {}
probabilitat = entrenamentSVM.predict_proba(testX)
#in range(2) porque mi variable objetivo es 1 o 0
for i in range(2):
    fpr[i], tpr[i],_  = roc_curve(testY == i, probabilitat[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
plt.figure()
for i in range(2):
    plt.plot(fpr[i], tpr[i], label='Class {0} (area = {1:0.2f})' ''.format(i, roc_auc[i]))
plt.legend()

# %%
confusion_matrix(testY,prediccioSVM)
plot_confusion_matrix(entrenamentSVM, testX, testY, cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# Podem veure que el SVM també dona molt bona accuracy, però que el resultat és dolent, ja que no hi ha cap true-negative, sinó que està tot a false-positive. Vol dir que aquest mètode ha interpretat que tots els casos eren positius.

# %% [markdown]
# ### KNN

# %% [markdown]
# Per últim provem el KNN

# %%
tempsInici = time.time()

#primer entrenem
entrenamentKNN = KNeighborsClassifier()
entrenamentKNN.fit(trainX,trainY)

#fem la prediccio
prediccioKNN = entrenamentKNN.predict(testX)

#calculem la accuracy
accuracyKNN = round(accuracy_score(testY, prediccioKNN)*100, 2)

print('accuracy KNN:')
print(round(accuracyKNN,2), '%')

print('temps:')
tempsFin = time.time()
print(tempsFin - tempsInici)
# Out:
# accuracy KNN:
# 98.72 %
# temps:
# 0.02707362174987793

# %% [markdown]
# Com el resultat és molt bo, mirem la corba roc per veure si és correcte o si hi ha hagut algun problema.

# %%
tempsInici = time.time()

fpr = {}
tpr = {}
roc_auc = {}
probabilitat = entrenamentKNN.predict_proba(testX)

#in range(2) porque mi variable objetivo es 1 o 0
for i in range(2):
    fpr[i], tpr[i],_  = roc_curve(testY == i, probabilitat[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
plt.figure()
for i in range(2):
    plt.plot(fpr[i], tpr[i], label='Class {0} (area = {1:0.2f})' ''.format(i, roc_auc[i]))
plt.legend()

print('temps:')
tempsFin = time.time()
print(tempsFin - tempsInici)
# Out:
# temps:
# 0.06867051124572754

# %%
confusion_matrix(testY,prediccioKNN)
plot_confusion_matrix(entrenamentKNN, testX, testY, cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# Observem que aquest últim model també dona resultats molt acceptables, molt semblants als resultats del decision tree.

# %% [markdown]
# ### Xarxa Neuronal

# %% [markdown]
# Generem la xarxa neuronal, fent 500 cicles

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(14,)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])


model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer='adam',
    metrics=["accuracy"]
)


# Iniciamos el entrenamiento
entrenamentRedNeuronal = model.fit(trainX,trainY,epochs=500)
# Out:
# Epoch 1/500
# 20/20 [==============================] - 2s 6ms/step - loss: 2.0451 - accuracy: 0.7276
# Epoch 2/500
# 20/20 [==============================] - 0s 6ms/step - loss: 1.6050 - accuracy: 0.9135
# Epoch 3/500
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1830 - accuracy: 0.9135
# Epoch 4/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.8159 - accuracy: 0.9135
# Epoch 5/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5740 - accuracy: 0.9135
# Epoch 6/500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4542 - accuracy: 0.9135
# Epoch 7/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3961 - accuracy: 0.9135
# Epoch 8/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3656 - accuracy: 0.9135
# Epoch 9/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3471 - accuracy: 0.9135
# Epoch 10/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3350 - accuracy: 0.9135
# Epoch 11/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3267 - accuracy: 0.9135
# Epoch 12/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3206 - accuracy: 0.9135
# Epoch 13/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3164 - accuracy: 0.9135
# Epoch 14/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3136 - accuracy: 0.9135
# Epoch 15/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3101 - accuracy: 0.9135
# Epoch 16/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3082 - accuracy: 0.9135
# Epoch 17/500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.3064 - accuracy: 0.9135
# Epoch 18/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3046 - accuracy: 0.9135
# Epoch 19/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3035 - accuracy: 0.9135
# Epoch 20/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3022 - accuracy: 0.9135
# Epoch 21/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3018 - accuracy: 0.9135
# Epoch 22/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3022 - accuracy: 0.9135
# Epoch 23/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3005 - accuracy: 0.9135
# Epoch 24/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2990 - accuracy: 0.9135
# Epoch 25/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2986 - accuracy: 0.9135
# Epoch 26/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2981 - accuracy: 0.9135
# Epoch 27/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2975 - accuracy: 0.9135
# Epoch 28/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2968 - accuracy: 0.9135
# Epoch 29/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2969 - accuracy: 0.9135
# Epoch 30/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2968 - accuracy: 0.9135
# Epoch 31/500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2957 - accuracy: 0.9135
# Epoch 32/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2950 - accuracy: 0.9135
# Epoch 33/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2951 - accuracy: 0.9135
# Epoch 34/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2953 - accuracy: 0.9135
# Epoch 35/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2941 - accuracy: 0.9135
# Epoch 36/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2939 - accuracy: 0.9135
# Epoch 37/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2936 - accuracy: 0.9135
# Epoch 38/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2934 - accuracy: 0.9135
# Epoch 39/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2931 - accuracy: 0.9135
# Epoch 40/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2927 - accuracy: 0.9135
# Epoch 41/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2925 - accuracy: 0.9135
# Epoch 42/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2920 - accuracy: 0.9135
# Epoch 43/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2916 - accuracy: 0.9135
# Epoch 44/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2916 - accuracy: 0.9135
# Epoch 45/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2912 - accuracy: 0.9135
# Epoch 46/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2911 - accuracy: 0.9135
# Epoch 47/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2905 - accuracy: 0.9135
# Epoch 48/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2903 - accuracy: 0.9135
# Epoch 49/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2905 - accuracy: 0.9135
# Epoch 50/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2911 - accuracy: 0.9135
# Epoch 51/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2895 - accuracy: 0.9135
# Epoch 52/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2897 - accuracy: 0.9135
# Epoch 53/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2891 - accuracy: 0.9135
# Epoch 54/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2885 - accuracy: 0.9135
# Epoch 55/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2883 - accuracy: 0.9135
# Epoch 56/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2885 - accuracy: 0.9135
# Epoch 57/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2882 - accuracy: 0.9135
# Epoch 58/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2872 - accuracy: 0.9135
# Epoch 59/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2871 - accuracy: 0.9135
# Epoch 60/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2866 - accuracy: 0.9135
# Epoch 61/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2873 - accuracy: 0.9135
# Epoch 62/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2863 - accuracy: 0.9135
# Epoch 63/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2857 - accuracy: 0.9135
# Epoch 64/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2859 - accuracy: 0.9135
# Epoch 65/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2852 - accuracy: 0.9135
# Epoch 66/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2854 - accuracy: 0.9135
# Epoch 67/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2842 - accuracy: 0.9135
# Epoch 68/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2856 - accuracy: 0.9135
# Epoch 69/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2839 - accuracy: 0.9135
# Epoch 70/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2835 - accuracy: 0.9135
# Epoch 71/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2827 - accuracy: 0.9135
# Epoch 72/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2828 - accuracy: 0.9135
# Epoch 73/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2824 - accuracy: 0.9135
# Epoch 74/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2822 - accuracy: 0.9135
# Epoch 75/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2815 - accuracy: 0.9135
# Epoch 76/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2810 - accuracy: 0.9135
# Epoch 77/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2812 - accuracy: 0.9135
# Epoch 78/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2801 - accuracy: 0.9135
# Epoch 79/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2801 - accuracy: 0.9135
# Epoch 80/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2791 - accuracy: 0.9135
# Epoch 81/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2797 - accuracy: 0.9135
# Epoch 82/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2798 - accuracy: 0.9135
# Epoch 83/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2794 - accuracy: 0.9135
# Epoch 84/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2783 - accuracy: 0.9135
# Epoch 85/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2767 - accuracy: 0.9135
# Epoch 86/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2766 - accuracy: 0.9135
# Epoch 87/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2775 - accuracy: 0.9135
# Epoch 88/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2757 - accuracy: 0.9135
# Epoch 89/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2749 - accuracy: 0.9135
# Epoch 90/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2743 - accuracy: 0.9135
# Epoch 91/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2738 - accuracy: 0.9135
# Epoch 92/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2731 - accuracy: 0.9135
# Epoch 93/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2726 - accuracy: 0.9135
# Epoch 94/500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2720 - accuracy: 0.9135
# Epoch 95/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2713 - accuracy: 0.9135
# Epoch 96/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2707 - accuracy: 0.9135
# Epoch 97/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2701 - accuracy: 0.9135
# Epoch 98/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2695 - accuracy: 0.9135
# Epoch 99/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2713 - accuracy: 0.9135
# Epoch 100/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2691 - accuracy: 0.9135
# Epoch 101/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2674 - accuracy: 0.9135
# Epoch 102/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2672 - accuracy: 0.9135
# Epoch 103/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2660 - accuracy: 0.9135
# Epoch 104/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2660 - accuracy: 0.9135
# Epoch 105/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2646 - accuracy: 0.9135
# Epoch 106/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2641 - accuracy: 0.9135
# Epoch 107/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2635 - accuracy: 0.9135
# Epoch 108/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2625 - accuracy: 0.9135
# Epoch 109/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2623 - accuracy: 0.9135
# Epoch 110/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2613 - accuracy: 0.9135
# Epoch 111/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2600 - accuracy: 0.9135
# Epoch 112/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2595 - accuracy: 0.9135
# Epoch 113/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2596 - accuracy: 0.9135
# Epoch 114/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2569 - accuracy: 0.9135
# Epoch 115/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2577 - accuracy: 0.9135
# Epoch 116/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2567 - accuracy: 0.9135
# Epoch 117/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2550 - accuracy: 0.9135
# Epoch 118/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2547 - accuracy: 0.9135
# Epoch 119/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2533 - accuracy: 0.9135
# Epoch 120/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2536 - accuracy: 0.9135
# Epoch 121/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2531 - accuracy: 0.9135
# Epoch 122/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2536 - accuracy: 0.9135
# Epoch 123/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2504 - accuracy: 0.9135
# Epoch 124/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2495 - accuracy: 0.9135
# Epoch 125/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2477 - accuracy: 0.9135
# Epoch 126/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2469 - accuracy: 0.9135
# Epoch 127/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2467 - accuracy: 0.9135
# Epoch 128/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2456 - accuracy: 0.9135
# Epoch 129/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2444 - accuracy: 0.9135
# Epoch 130/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2433 - accuracy: 0.9135
# Epoch 131/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2427 - accuracy: 0.9135
# Epoch 132/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2411 - accuracy: 0.9135
# Epoch 133/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2399 - accuracy: 0.9135
# Epoch 134/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2392 - accuracy: 0.9135
# Epoch 135/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2380 - accuracy: 0.9135
# Epoch 136/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2372 - accuracy: 0.9135
# Epoch 137/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2355 - accuracy: 0.9135
# Epoch 138/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2356 - accuracy: 0.9135
# Epoch 139/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2348 - accuracy: 0.9135
# Epoch 140/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2330 - accuracy: 0.9135
# Epoch 141/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2310 - accuracy: 0.9135
# Epoch 142/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2306 - accuracy: 0.9135
# Epoch 143/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2289 - accuracy: 0.9135
# Epoch 144/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2280 - accuracy: 0.9135
# Epoch 145/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2280 - accuracy: 0.9135
# Epoch 146/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2258 - accuracy: 0.9135
# Epoch 147/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2236 - accuracy: 0.9135
# Epoch 148/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2238 - accuracy: 0.9135
# Epoch 149/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2225 - accuracy: 0.9135
# Epoch 150/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2211 - accuracy: 0.9135
# Epoch 151/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2194 - accuracy: 0.9135
# Epoch 152/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2191 - accuracy: 0.9135
# Epoch 153/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2173 - accuracy: 0.9135
# Epoch 154/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2165 - accuracy: 0.9135
# Epoch 155/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2181 - accuracy: 0.9135
# Epoch 156/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2157 - accuracy: 0.9135
# Epoch 157/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2141 - accuracy: 0.9135
# Epoch 158/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2115 - accuracy: 0.9135
# Epoch 159/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2111 - accuracy: 0.9135
# Epoch 160/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2089 - accuracy: 0.9135
# Epoch 161/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2093 - accuracy: 0.9135
# Epoch 162/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2065 - accuracy: 0.9135
# Epoch 163/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2051 - accuracy: 0.9135
# Epoch 164/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2041 - accuracy: 0.9135
# Epoch 165/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2029 - accuracy: 0.9135
# Epoch 166/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2011 - accuracy: 0.9135
# Epoch 167/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1994 - accuracy: 0.9135
# Epoch 168/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2010 - accuracy: 0.9135
# Epoch 169/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2001 - accuracy: 0.9135
# Epoch 170/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1989 - accuracy: 0.9135
# Epoch 171/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1951 - accuracy: 0.9135
# Epoch 172/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1938 - accuracy: 0.9135
# Epoch 173/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1933 - accuracy: 0.9135
# Epoch 174/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1915 - accuracy: 0.9135
# Epoch 175/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1896 - accuracy: 0.9135
# Epoch 176/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1886 - accuracy: 0.9135
# Epoch 177/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1872 - accuracy: 0.9135
# Epoch 178/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1863 - accuracy: 0.9135
# Epoch 179/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1852 - accuracy: 0.9135
# Epoch 180/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1836 - accuracy: 0.9135
# Epoch 181/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1830 - accuracy: 0.9135
# Epoch 182/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1828 - accuracy: 0.9183
# Epoch 183/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1800 - accuracy: 0.9135
# Epoch 184/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1794 - accuracy: 0.9135
# Epoch 185/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1793 - accuracy: 0.9183
# Epoch 186/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1780 - accuracy: 0.9135
# Epoch 187/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1755 - accuracy: 0.9183
# Epoch 188/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.9183
# Epoch 189/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1729 - accuracy: 0.9183
# Epoch 190/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1731 - accuracy: 0.9167
# Epoch 191/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1707 - accuracy: 0.9183
# Epoch 192/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1695 - accuracy: 0.9183
# Epoch 193/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1682 - accuracy: 0.9183
# Epoch 194/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1673 - accuracy: 0.9183
# Epoch 195/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1668 - accuracy: 0.9199
# Epoch 196/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1661 - accuracy: 0.9183
# Epoch 197/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1636 - accuracy: 0.9183
# Epoch 198/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1641 - accuracy: 0.9199
# Epoch 199/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1613 - accuracy: 0.9183
# Epoch 200/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1627 - accuracy: 0.9183
# Epoch 201/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1603 - accuracy: 0.9615
# Epoch 202/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1594 - accuracy: 0.9183
# Epoch 203/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1590 - accuracy: 0.9295
# Epoch 204/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1569 - accuracy: 0.9487
# Epoch 205/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1554 - accuracy: 0.9551
# Epoch 206/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1547 - accuracy: 0.9215
# Epoch 207/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1535 - accuracy: 0.9647
# Epoch 208/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1525 - accuracy: 0.9423
# Epoch 209/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1516 - accuracy: 0.9647
# Epoch 210/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1506 - accuracy: 0.9615
# Epoch 211/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1491 - accuracy: 0.9647
# Epoch 212/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1480 - accuracy: 0.9647
# Epoch 213/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1475 - accuracy: 0.9647
# Epoch 214/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1475 - accuracy: 0.9647
# Epoch 215/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1460 - accuracy: 0.9647
# Epoch 216/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1445 - accuracy: 0.9647
# Epoch 217/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1450 - accuracy: 0.9647
# Epoch 218/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1436 - accuracy: 0.9647
# Epoch 219/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1420 - accuracy: 0.9647
# Epoch 220/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1419 - accuracy: 0.9647
# Epoch 221/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1414 - accuracy: 0.9647
# Epoch 222/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1402 - accuracy: 0.9647
# Epoch 223/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1413 - accuracy: 0.9647
# Epoch 224/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1395 - accuracy: 0.9647
# Epoch 225/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1377 - accuracy: 0.9647
# Epoch 226/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1363 - accuracy: 0.9647
# Epoch 227/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1354 - accuracy: 0.9647
# Epoch 228/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1367 - accuracy: 0.9647
# Epoch 229/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1351 - accuracy: 0.9647
# Epoch 230/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1336 - accuracy: 0.9647
# Epoch 231/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1323 - accuracy: 0.9647
# Epoch 232/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1323 - accuracy: 0.9647
# Epoch 233/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1311 - accuracy: 0.9647
# Epoch 234/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1305 - accuracy: 0.9647
# Epoch 235/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1301 - accuracy: 0.9647
# Epoch 236/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1303 - accuracy: 0.9647
# Epoch 237/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1291 - accuracy: 0.9647
# Epoch 238/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1295 - accuracy: 0.9647
# Epoch 239/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1278 - accuracy: 0.9647
# Epoch 240/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1274 - accuracy: 0.9647
# Epoch 241/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1263 - accuracy: 0.9647
# Epoch 242/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1261 - accuracy: 0.9647
# Epoch 243/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1250 - accuracy: 0.9647
# Epoch 244/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1245 - accuracy: 0.9647
# Epoch 245/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1258 - accuracy: 0.9647
# Epoch 246/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1280 - accuracy: 0.9647
# Epoch 247/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1224 - accuracy: 0.9647
# Epoch 248/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.9647
# Epoch 249/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1215 - accuracy: 0.9647
# Epoch 250/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1213 - accuracy: 0.9647
# Epoch 251/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1207 - accuracy: 0.9647
# Epoch 252/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1216 - accuracy: 0.9647
# Epoch 253/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1199 - accuracy: 0.9647
# Epoch 254/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1188 - accuracy: 0.9647
# Epoch 255/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1199 - accuracy: 0.9647
# Epoch 256/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1185 - accuracy: 0.9647
# Epoch 257/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1190 - accuracy: 0.9647
# Epoch 258/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1174 - accuracy: 0.9647
# Epoch 259/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1169 - accuracy: 0.9647
# Epoch 260/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1161 - accuracy: 0.9647
# Epoch 261/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1165 - accuracy: 0.9647
# Epoch 262/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1155 - accuracy: 0.9647
# Epoch 263/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1145 - accuracy: 0.9647
# Epoch 264/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1154 - accuracy: 0.9647
# Epoch 265/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1147 - accuracy: 0.9647
# Epoch 266/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1135 - accuracy: 0.9647
# Epoch 267/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1153 - accuracy: 0.9647
# Epoch 268/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1143 - accuracy: 0.9647
# Epoch 269/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1127 - accuracy: 0.9647
# Epoch 270/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1133 - accuracy: 0.9647
# Epoch 271/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1132 - accuracy: 0.9647
# Epoch 272/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1113 - accuracy: 0.9647
# Epoch 273/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1111 - accuracy: 0.9647
# Epoch 274/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1113 - accuracy: 0.9647
# Epoch 275/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1108 - accuracy: 0.9647
# Epoch 276/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1104 - accuracy: 0.9647
# Epoch 277/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1116 - accuracy: 0.9647
# Epoch 278/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1102 - accuracy: 0.9647
# Epoch 279/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1092 - accuracy: 0.9647
# Epoch 280/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1098 - accuracy: 0.9647
# Epoch 281/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1094 - accuracy: 0.9647
# Epoch 282/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1090 - accuracy: 0.9647
# Epoch 283/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1079 - accuracy: 0.9647
# Epoch 284/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1075 - accuracy: 0.9647
# Epoch 285/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1080 - accuracy: 0.9647
# Epoch 286/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1079 - accuracy: 0.9647
# Epoch 287/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1070 - accuracy: 0.9647
# Epoch 288/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1067 - accuracy: 0.9647
# Epoch 289/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1068 - accuracy: 0.9647
# Epoch 290/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1065 - accuracy: 0.9647
# Epoch 291/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1063 - accuracy: 0.9647
# Epoch 292/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1064 - accuracy: 0.9647
# Epoch 293/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1060 - accuracy: 0.9647
# Epoch 294/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1070 - accuracy: 0.9647
# Epoch 295/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1062 - accuracy: 0.9647
# Epoch 296/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1054 - accuracy: 0.9647
# Epoch 297/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1052 - accuracy: 0.9647
# Epoch 298/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1056 - accuracy: 0.9647
# Epoch 299/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1080 - accuracy: 0.9647
# Epoch 300/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1047 - accuracy: 0.9647
# Epoch 301/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1040 - accuracy: 0.9647
# Epoch 302/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1042 - accuracy: 0.9647
# Epoch 303/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1039 - accuracy: 0.9647
# Epoch 304/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1028 - accuracy: 0.9647
# Epoch 305/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1029 - accuracy: 0.9647
# Epoch 306/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1034 - accuracy: 0.9647
# Epoch 307/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1028 - accuracy: 0.9647
# Epoch 308/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1041 - accuracy: 0.9647
# Epoch 309/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1025 - accuracy: 0.9647
# Epoch 310/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1015 - accuracy: 0.9647
# Epoch 311/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1022 - accuracy: 0.9647
# Epoch 312/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1017 - accuracy: 0.9647
# Epoch 313/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1017 - accuracy: 0.9647
# Epoch 314/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1014 - accuracy: 0.9647
# Epoch 315/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1010 - accuracy: 0.9647
# Epoch 316/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1012 - accuracy: 0.9647
# Epoch 317/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1016 - accuracy: 0.9647
# Epoch 318/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1010 - accuracy: 0.9647
# Epoch 319/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1005 - accuracy: 0.9647
# Epoch 320/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1010 - accuracy: 0.9647
# Epoch 321/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1006 - accuracy: 0.9647
# Epoch 322/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1000 - accuracy: 0.9647
# Epoch 323/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1001 - accuracy: 0.9647
# Epoch 324/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0999 - accuracy: 0.9647
# Epoch 325/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0995 - accuracy: 0.9647
# Epoch 326/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0997 - accuracy: 0.9647
# Epoch 327/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0998 - accuracy: 0.9647
# Epoch 328/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1000 - accuracy: 0.9647
# Epoch 329/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1006 - accuracy: 0.9647
# Epoch 330/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0993 - accuracy: 0.9647
# Epoch 331/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0995 - accuracy: 0.9647
# Epoch 332/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0988 - accuracy: 0.9647
# Epoch 333/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0987 - accuracy: 0.9647
# Epoch 334/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1000 - accuracy: 0.9647
# Epoch 335/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1007 - accuracy: 0.9712
# Epoch 336/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0999 - accuracy: 0.9647
# Epoch 337/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0982 - accuracy: 0.9647
# Epoch 338/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0981 - accuracy: 0.9647
# Epoch 339/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0984 - accuracy: 0.9647
# Epoch 340/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0978 - accuracy: 0.9647
# Epoch 341/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0986 - accuracy: 0.9647
# Epoch 342/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0982 - accuracy: 0.9679
# Epoch 343/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1003 - accuracy: 0.9647
# Epoch 344/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0974 - accuracy: 0.9647
# Epoch 345/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0979 - accuracy: 0.9663
# Epoch 346/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0974 - accuracy: 0.9647
# Epoch 347/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0990 - accuracy: 0.9696
# Epoch 348/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0983 - accuracy: 0.9647
# Epoch 349/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0976 - accuracy: 0.9647
# Epoch 350/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0973 - accuracy: 0.9647
# Epoch 351/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0969 - accuracy: 0.9647
# Epoch 352/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0972 - accuracy: 0.9647
# Epoch 353/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0974 - accuracy: 0.9679
# Epoch 354/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0968 - accuracy: 0.9647
# Epoch 355/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0989 - accuracy: 0.9679
# Epoch 356/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0965 - accuracy: 0.9712
# Epoch 357/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0965 - accuracy: 0.9647
# Epoch 358/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0985 - accuracy: 0.9792
# Epoch 359/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0981 - accuracy: 0.9647
# Epoch 360/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0960 - accuracy: 0.9760
# Epoch 361/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0969 - accuracy: 0.9808
# Epoch 362/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0973 - accuracy: 0.9647
# Epoch 363/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0965 - accuracy: 0.9712
# Epoch 364/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0964 - accuracy: 0.9647
# Epoch 365/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0986 - accuracy: 0.9712
# Epoch 366/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0960 - accuracy: 0.9647
# Epoch 367/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0964 - accuracy: 0.9647
# Epoch 368/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0978 - accuracy: 0.9856
# Epoch 369/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0963 - accuracy: 0.9647
# Epoch 370/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0951 - accuracy: 0.9647
# Epoch 371/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0978 - accuracy: 0.9872
# Epoch 372/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1010 - accuracy: 0.9647
# Epoch 373/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0992 - accuracy: 0.9776
# Epoch 374/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0958 - accuracy: 0.9856
# Epoch 375/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0954 - accuracy: 0.9647
# Epoch 376/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0963 - accuracy: 0.9679
# Epoch 377/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0951 - accuracy: 0.9744
# Epoch 378/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0955 - accuracy: 0.9663
# Epoch 379/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0951 - accuracy: 0.9744
# Epoch 380/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0955 - accuracy: 0.9792
# Epoch 381/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0965 - accuracy: 0.9647
# Epoch 382/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0988 - accuracy: 0.9792
# Epoch 383/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0965 - accuracy: 0.9647
# Epoch 384/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0971 - accuracy: 0.9647
# Epoch 385/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0961 - accuracy: 0.9872
# Epoch 386/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0962 - accuracy: 0.9647
# Epoch 387/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0946 - accuracy: 0.9647
# Epoch 388/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0949 - accuracy: 0.9856
# Epoch 389/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0954 - accuracy: 0.9647
# Epoch 390/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0959 - accuracy: 0.9776
# Epoch 391/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0943 - accuracy: 0.9679
# Epoch 392/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0948 - accuracy: 0.9696
# Epoch 393/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0943 - accuracy: 0.9872
# Epoch 394/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0950 - accuracy: 0.9728
# Epoch 395/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0954 - accuracy: 0.9679
# Epoch 396/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0945 - accuracy: 0.9760
# Epoch 397/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0942 - accuracy: 0.9856
# Epoch 398/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0947 - accuracy: 0.9663
# Epoch 399/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0944 - accuracy: 0.9760
# Epoch 400/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0943 - accuracy: 0.9712
# Epoch 401/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0942 - accuracy: 0.9760
# Epoch 402/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0943 - accuracy: 0.9696
# Epoch 403/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0941 - accuracy: 0.9744
# Epoch 404/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0957 - accuracy: 0.9712
# Epoch 405/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0948 - accuracy: 0.9808
# Epoch 406/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0941 - accuracy: 0.9840
# Epoch 407/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0950 - accuracy: 0.9856
# Epoch 408/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0951 - accuracy: 0.9792
# Epoch 409/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0946 - accuracy: 0.9647
# Epoch 410/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0958 - accuracy: 0.9856
# Epoch 411/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0944 - accuracy: 0.9647
# Epoch 412/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0942 - accuracy: 0.9840
# Epoch 413/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0941 - accuracy: 0.9840
# Epoch 414/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0938 - accuracy: 0.9808
# Epoch 415/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0944 - accuracy: 0.9712
# Epoch 416/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0950 - accuracy: 0.9872
# Epoch 417/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0960 - accuracy: 0.9679
# Epoch 418/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0945 - accuracy: 0.9872
# Epoch 419/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0949 - accuracy: 0.9696
# Epoch 420/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0951 - accuracy: 0.9728
# Epoch 421/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0938 - accuracy: 0.9872
# Epoch 422/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0940 - accuracy: 0.9760
# Epoch 423/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0937 - accuracy: 0.9760
# Epoch 424/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0940 - accuracy: 0.9840
# Epoch 425/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0935 - accuracy: 0.9792
# Epoch 426/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0941 - accuracy: 0.9728
# Epoch 427/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0948 - accuracy: 0.9808
# Epoch 428/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0965 - accuracy: 0.9872
# Epoch 429/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0963 - accuracy: 0.9647
# Epoch 430/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0941 - accuracy: 0.9744
# Epoch 431/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0944 - accuracy: 0.9776
# Epoch 432/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0941 - accuracy: 0.9872
# Epoch 433/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0952 - accuracy: 0.9744
# Epoch 434/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0943 - accuracy: 0.9792
# Epoch 435/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0935 - accuracy: 0.9856
# Epoch 436/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0937 - accuracy: 0.9696
# Epoch 437/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0942 - accuracy: 0.9872
# Epoch 438/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0931 - accuracy: 0.9872
# Epoch 439/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0936 - accuracy: 0.9760
# Epoch 440/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0935 - accuracy: 0.9840
# Epoch 441/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0934 - accuracy: 0.9840
# Epoch 442/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0957 - accuracy: 0.9872
# Epoch 443/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0963 - accuracy: 0.9647
# Epoch 444/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0938 - accuracy: 0.9840
# Epoch 445/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0938 - accuracy: 0.9792
# Epoch 446/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0942 - accuracy: 0.9728
# Epoch 447/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0939 - accuracy: 0.9872
# Epoch 448/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0932 - accuracy: 0.9872
# Epoch 449/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0936 - accuracy: 0.9712
# Epoch 450/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0935 - accuracy: 0.9872
# Epoch 451/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0932 - accuracy: 0.9872
# Epoch 452/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0932 - accuracy: 0.9776
# Epoch 453/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0941 - accuracy: 0.9872
# Epoch 454/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0935 - accuracy: 0.9792
# Epoch 455/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0941 - accuracy: 0.9872
# Epoch 456/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0944 - accuracy: 0.9776
# Epoch 457/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0927 - accuracy: 0.9872
# Epoch 458/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0928 - accuracy: 0.9872
# Epoch 459/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0936 - accuracy: 0.9760
# Epoch 460/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0940 - accuracy: 0.9872
# Epoch 461/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0928 - accuracy: 0.9872
# Epoch 462/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0924 - accuracy: 0.9872
# Epoch 463/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0925 - accuracy: 0.9872
# Epoch 464/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0927 - accuracy: 0.9856
# Epoch 465/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0934 - accuracy: 0.9872
# Epoch 466/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0925 - accuracy: 0.9872
# Epoch 467/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0922 - accuracy: 0.9872
# Epoch 468/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0921 - accuracy: 0.9872
# Epoch 469/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0933 - accuracy: 0.9872
# Epoch 470/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0924 - accuracy: 0.9872
# Epoch 471/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0922 - accuracy: 0.9872
# Epoch 472/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0921 - accuracy: 0.9808
# Epoch 473/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0919 - accuracy: 0.9872
# Epoch 474/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0927 - accuracy: 0.9872
# Epoch 475/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0928 - accuracy: 0.9872
# Epoch 476/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0932 - accuracy: 0.9679
# Epoch 477/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0945 - accuracy: 0.9872
# Epoch 478/500
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0921 - accuracy: 0.9856
# Epoch 479/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0922 - accuracy: 0.9872
# Epoch 480/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0923 - accuracy: 0.9872
# Epoch 481/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0923 - accuracy: 0.9872
# Epoch 482/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0922 - accuracy: 0.9872
# Epoch 483/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0917 - accuracy: 0.9872
# Epoch 484/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0927 - accuracy: 0.9872
# Epoch 485/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0939 - accuracy: 0.9872
# Epoch 486/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0930 - accuracy: 0.9744
# Epoch 487/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0922 - accuracy: 0.9872
# Epoch 488/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0929 - accuracy: 0.9872
# Epoch 489/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0921 - accuracy: 0.9872
# Epoch 490/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0918 - accuracy: 0.9872
# Epoch 491/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0915 - accuracy: 0.9872
# Epoch 492/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0935 - accuracy: 0.9872
# Epoch 493/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0922 - accuracy: 0.9872
# Epoch 494/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0916 - accuracy: 0.9872
# Epoch 495/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0918 - accuracy: 0.9872
# Epoch 496/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0917 - accuracy: 0.9872
# Epoch 497/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0919 - accuracy: 0.9872
# Epoch 498/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0922 - accuracy: 0.9872
# Epoch 499/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0922 - accuracy: 0.9872
# Epoch 500/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0930 - accuracy: 0.9872

# %% [markdown]
# Aquí podem observar com va augmentant l'accuracy amb cada cicle. Cal destacar que l'accuracy és constant fins al voltant del cicle 200.

# %%
model.evaluate(testX,testY)
# Out:
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0603 - accuracy: 0.9936
# [0.06026186794042587, 0.9935897588729858]

# %% [markdown]
# Aqui observem el resultat final de la nostra xarxa neuronal.

# %%
plt.xlabel("cicles")
plt.ylabel("Accuracy")
plt.plot(entrenamentRedNeuronal.history["accuracy"])

# %% [markdown]
# Aquí la xarxa neuronal mostrada amb una gràfica per veure millor com va evolucionant l'accuracy amb els cicles.

# %% [markdown]
# # Conclusions

# %% [markdown]
# Podem veure que aquesta és una BD molt senzilla, ja que només té 800 files, que pertanyen cadascuna a un del Pokémon existents, això ha causat alguns petits problemes que no es poden evitar, perquè l'única manera d'ampliar aquesta BD seria afegint informació de Pokémon de futures generacions.
#
# A l'inici del tractament he tingut dificultats a causa dels valors null que hi havia originalment a la BD, ja que afectaven molt a les porques files on la variable objectiu valia 1. Però una vegada arreglats tot ha funcionat correctament.
#
# Després de fer els models hem vist que l'únic que dona problemes és el SVM, pel fet que encara que la seva accuracy és bona el resultat no ho és, perquè a la confusion matrix es pot veure que no hi ha cap true-negative, sinó que tot són false-positives o true-positives. Això vol dir que està classificant tot com a true, i l'accuracy alta és deguda al fet que hi ha poc nombre de resultats negatius respecte als positius.
# La resta de models han funcionat correctament, donant bona accuracy, corbes roc i confusion matrix.
